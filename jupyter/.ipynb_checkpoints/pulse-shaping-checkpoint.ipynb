# %% [markdown]
# # Pulse-shaping

# %%
import numpy as np

x = np.random.uniform(-1, +1, 10)
n = np.arange(len(x))

from matplotlib import pyplot as plt

plt.title('Samples')
plt.scatter(n, x)
plt.show()

# %%
plt.title('Upsampling')
plt.scatter(n, x)
plt.show()
